# %% [markdown]
# # diff_abs

# %% [markdown]
# ## 데이터 불러오기, 정렬

# %%
import pandas as pd

# %%
data = pd.read_csv("preds.csv")

# %%
data.set_index("index", inplace = True)
data.head()
# Out:
#          Mean_H    Mean_S    Mean_V  duration  paidBadge      bday      subs  \
# index
# 1056   0.353333  0.177083  0.738462  0.763636          1  0.723039  0.498438
# 109    0.060000  0.312500  0.794872  0.981818          1  0.541141  0.779173
# 1867   0.340000  0.708333  0.676923  1.000000          1  0.118873  0.600843
# 1817   0.206667  0.645833  0.779487  0.527273          1  0.061800  0.653933
# 322    0.193333  0.635417  0.553846  0.709091          1  0.441877  0.585686
#
#        prettyScale  publishedAt  videoTitle   tag  face_area_ratio  \
# index
# 1056      0.674074     0.116474    0.180851  0.00         0.067883
# 109       0.622222     0.053411    0.276596  0.32         0.681944
# 1867      0.540741     0.147362    0.968085  0.00         0.000000
# 1817      0.000000     0.111326    0.127660  0.00         1.000000
# 322       0.614815     0.017375    0.882979  0.00         0.658190
#
#        text_rate1     tempo   f0_mean    f0_var  y_predict    y_truth  \
# index
# ...

# %%
data = data.sort_values("diff_abs")

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data_head100
# Out:
#          Mean_H    Mean_S    Mean_V  duration  paidBadge      bday      subs  \
# index
# 1084   0.900000  0.229167  0.846154  0.981818          1  0.567227  1.000000
# 1431   0.073333  0.364583  0.717949  0.818182          1  0.278536  0.429193
# 1113   0.540000  0.458333  0.620513  0.181818          1  0.685049  0.656151
# 1468   0.186667  0.427083  0.246154  0.327273          1  0.329307  0.724741
# 2143   0.773333  0.375000  0.594872  0.545455          1  0.429797  0.607293
# ...         ...       ...       ...       ...        ...       ...       ...
# 111    0.113333  0.833333  0.497436  0.909091          1  0.324230  0.763536
# 58     0.053333  0.520833  0.933333  0.472727          1  0.914391  0.538091
# 383    0.660000  0.093750  0.405128  0.709091          0  0.723039  0.498438
# 1042   0.653333  0.229167  0.830769  0.890909          0  0.602066  0.751242
# 906    0.366667  0.812500  0.487179  0.763636          0  0.609069  0.720966
#
# ...

# %% [markdown]
# ## 시각화

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def plot_column(column):
    plt.figure(figsize = (8, 6))
    sns.histplot(data_head100[column], bins = 50, alpha = 0.5, label = "head")
    sns.histplot(data_tail100[column], bins = 50, alpha = 0.5, label = "tail")
    plt.title(column)
    plt.legend()
    plt.show()

# %%
plot_column("tempo")

# %%
plot_column("prettyScale")

# %%
plot_column("videoTitle")

# %%
plot_column("bday")

# %%
plot_column("subs")

# %%
plot_column("tag")

# %%
plot_column("face_area_ratio")

# %%
plot_column("f0_mean")

# %%
plot_column("f0_var")

# %%
plot_column("publishedAt")

# %%
plot_column("Mean_H")

# %%
plot_column("Mean_S")

# %%
plot_column("Mean_V")

# %% [markdown]
# > 유의미한 데이터 분포도 차이가 시각화로 보이지 않는 관계로 예측값의 차(절댓값)를 가지고 의미 도출은 어려워 보임.
